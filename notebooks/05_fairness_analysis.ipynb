# %%
from src.fairness import fairness_check

fairness_gender = fairness_check(model, X_test, y_test, "gender")
fairness_res = fairness_check(model, X_test, y_test, "Residence_type")

fairness_gender
fairness_res
