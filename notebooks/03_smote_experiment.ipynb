# %%
from src.oversampling import apply_smote

X_smote, y_smote = apply_smote(X_train, y_train)

model.fit(X_smote, y_smote)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
