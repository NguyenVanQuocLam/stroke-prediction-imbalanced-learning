# %%
from src.oversampling import apply_ctgan

X_gan, y_gan = apply_ctgan(X_train, y_train)

model.fit(X_gan, y_gan)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-571/638883662.py in <cell line: 0>()
# ----> 1 from src.oversampling import apply_smote
#       2
#       3 X_smote, y_smote = apply_smote(X_train, y_train)
#       4
#       5 model.fit(X_smote, y_smote)
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
