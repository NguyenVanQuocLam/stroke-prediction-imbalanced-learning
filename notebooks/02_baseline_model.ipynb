# %%
from sklearn.metrics import classification_report, roc_auc_score
from src.data_loader import load_data
from src.preprocessing import build_preprocessor
from src.models import build_logistic

X_train, X_test, y_train, y_test = load_data("../stroke_dataset.csv")

preprocessor = build_preprocessor(X_train)
model = build_logistic(preprocessor)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-571/1351771242.py in <cell line: 0>()
#       1 from sklearn.metrics import classification_report, roc_auc_score
# ----> 2 from src.data_loader import load_data
#       3 from src.preprocessing import build_preprocessor
#       4 from src.models import build_logistic
#       5
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
